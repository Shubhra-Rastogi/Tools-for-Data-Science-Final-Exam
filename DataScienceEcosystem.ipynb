# %% [markdown]
# # IBM Course 2 Final Exam
# Working with Jupyter Notebook, execute the following commands and upload for peer review

# %% [markdown]
# ### Exercise 1: Create a Jupyter Notebook
# Create a new Jupyter notebook called DataScienceEcosystem.ipynb

# %% [markdown]
# ![1-notebook.png](attachment:486b116a-c65a-4c92-a0f4-ef67e57dd95c.png)

# %% [markdown]
# ### Exercise 2: Create markdown cell with title of the notebook
# Create a markdown cell with the title Data Science Tools and Ecosystem using H1 style heading..)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:668d98ab-1c74-45fd-918d-6bee8b3267ac.png)

# %% [markdown]
# ## Exercise 3 - Create a markdown cell for an introduction
#
# Write an introductory sentence about the notebook

# %% [markdown]
# *Data Science Tools and Ecosystems are summarized in this notebook. Prompts are provided by the IBM Data Science Course Final Exam to test execution of markdown, jupyter commands, and github.*

# %% [markdown]
# ![3-intro.png](attachment:a74ae9aa-f833-4874-bf5a-ead8b368f946.png)

# %% [markdown]
# **Objectives**
#
# * Create a markdown cell to list data science languages
# * Create a markdown cell with a table of Data Science tools
# * Create a code cell to multiply and add numbers
# * Create a code cell to convert minutes to hours

# %% [markdown]
# ![10-objectives.png](attachment:99c92792-2ff4-4a97-a28e-34dcd358c6f5.png)

# %% [markdown]
# ### Exercise 4 - Create a markdown cell to list data science languages
#
# Start the cell with an overview line, then en create an ordered list (i.e. numbered) listing 3 (or more) commonly used languages for data scien)

# %% [markdown]
# #### Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java

# %% [markdown]
# ![4-dslanguages.png](attachment:22c7cdd1-c07e-49fc-803c-6fe7ceebcd00.png)

# %% [markdown]
# ### Exercise 5 - Create a markdown cell to list data science libraries
# Add an overview line to the cell. :
# Below this line add an ordered list listing 3 (or more) commonly used libraries in data science.

# %% [markdown]
# #### Some of the commonly used libraries used by Data Scientists include:
#
# 1. pandas
# 2. numpy
# 3. sklearn
# 4. seaborn

# %% [markdown]
# ![5-dslibraries.png](attachment:4d563ac5-e951-4426-a0cb-e57afbaf86d0.png)

# %% [markdown]
# ### Exercise 6 - Create a markdown cell with a table of Data Science tools
# Create a single column table in this cell with the first row containing the header Data Science Tools. The subsequent three rows in the table should indicate three development environment open source tools used in data science.

# %% [markdown]
# | Data Science Tools |
# |:------------------:
# |     TensorFlow     |
# |     ApacheSpark    |
# |     PyCharm        || 3   |

# %% [markdown]
# ![6-dstools.PNG](attachment:9cd05d22-bd65-404f-832c-09cedac1c7b2.PNG)

# %% [markdown]
# ### Exercise 7 - Create a markdown cell introducing arithmetic expression examples
#
# Add a line in this cell with H3 style heading

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![7-introarithmetic.png](attachment:b3b946d6-80df-4977-ae13-d8fdf843f9bf.png)

# %% [markdown]
# ### Exercise 8 - Create a code cell to multiply and add numbers
# In this code cell evaluate the expression (3*4)+5.
# Insert a comment line before the expression to explain the operatio..
# Then execute the cell to ensure the expression returns the expected outp.ut

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ### Exercise 9 - Create a code cell to convert minutes to hours
# In this code cell write an expression that converts 200 minutes into hours.
# Insert a comment line before the expression to explain the operatio, Run the cell to evaluate the expression.
# n

# %%
# This expression will convert 200 minutes to hours
hours, minutes = divmod(200, 60)
print ("200 minutes is", hours, "hours and", minutes, "minutes")
# Out:
# 200 minutes is 3 hours and 20 minutes

# %% [markdown]
# ### Exercise 10 - Insert a markdown cell to list Objectives
#
# Below the introduction cell created in Exercise 3, insert a new markdown cell to list the objectives that this notebook covered (i.e. some of the key takeaways from the course). In this new cell start with an introductory line titled: Objectives: in bold font. Then using an unordered list (bullets) indicate 3 to 5 items covered in this notebook, such as List popular languages for Data Science.

# %% [markdown]
# ### Exercise 11 - Create a markdown cell to indicate the Author's name
# In this markdown cell markdown cell include the following text Author in H2 style heading. Include your name as regular text below the word Author.

# %% [markdown]
# ## Author
# Shubhra Rastogi

# %% [markdown]
# ![11-authordetails.png](attachment:d9edb153-d6ed-4edc-902e-6fd40ea88b68.png)
